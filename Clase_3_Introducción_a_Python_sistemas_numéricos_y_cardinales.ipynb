# %%
Introducion a Python. sistemas numericos y cardinales

# %% [markdown]
# # ¿Que es Python ?
#
#  es un lenguaje Capaz de adaptarse con facilidad , utilizado en diversas industrias y para múltiples aplicaciones, desde desarrollo web hasta ciencia de datos. Aprender Python no solo aumenta tus habilidades de programación, sino que también abre puertas a numerosas oportunidades profesionales.
#
#
#
# *   Solo puede ejecutar operaciones muy basicas
# *   Su podr radica en la rapidez para ejecutar, y repetirlas tantas beses sean necesarios
#
# **Un ejemplo práctico: calculando la velocidad media** 🏎️
#
# Supongamos que quieres calcular la velocidad media de un viaje en coche. Tienes la distancia recorrida y el tiempo que te ha llevado.
#
# ¿Cómo harías que una computadora calcule la velocidad media?
#
# Tendrías que darle instrucciones muy claras y paso a paso:
#
# 1.Acepta un número que represente la distancia recorrida
#
# 2.Acepta un número que represente el tiempo que ha llevado el viaje
#
# 3.Divide el primer número (distancia) por el segundo número (tiempo)
# 4.para obtener la velocidad media
#
# 5.Muestra el resultado de una forma que sea fácil de entender para un humano
#
#
# ***Lenguajes Naturales vs Lenguajes de Programación***🌍 🖥️
#
# Los lenguajes son herramientas  para expresar y registrar pensamientos. 💭 Hay muchos tipos de lenguajes a nuestro alrededor, como el lenguaje corporal, ni siquiera requieren hablar o escribir.🤫
#
# **Lenguajes Naturales** 🌍🗣️
#
# Usamos lenguajes naturales, como nuestra lengua materna, cada día para comunicarnos y reflexionar sobre el mundo que nos rodea. Estos lenguajes evolucionan orgánicamente con el tiempo, con nuevas palabras surgiendo y otras cayendo en desuso.
#
# **Ejemplo**🤓
#
# Un ejemplo claro de cómo los lenguajes naturales evolucionan es el término "teléfono móvil". Hace unas décadas, este dispositivo era conocido comúnmente como "celular" en muchos países de habla hispana.  adaptación lingüística a nuevos contextos y necesidades
#
# **Lenguajes de Programación** 💻
#
# Por otro lado, las computadoras tienen sus propios lenguajes, llamados lenguajes de programación. A diferencia de los lenguajes naturales, estos son muy estructurados y precisos.
#
# **Un ejemplo** claro de un lenguaje de programación estructurado y preciso es Python. Python es conocido por su sintaxis limpia y legible, lo que lo hace especialmente popular entre principiantes y profesionales por igual
#
# ![WhatsApp Image 2024-06-30 at 2.10.03 PM.jpeg](data:image/jpeg;base64,...)
#
#
# 3 **¿Qué compone a un lenguaje?** 🌐
#
#
#
# *   Alfabeto📚
#
# *  :Léxico📘
#
# *    Sintaxis🧐
#
# *   Semántica🌝
#
# ***4 Lenguaje máquina vs. lenguaje de alto nivel***
#
# * Lenguaje máquina: el alfabeto de las computadoras
#
# * El puente entre dos mundos: lenguajes de alto nivel
#
# * Código fuente: el manuscrito de un programa
#
# **5 Compilación vs. Interpretación**
# *Alfabéticamente *😀 - El programa debe estar escrito en alfabeto reconocible, como el romano o el cirílico.
#
# *Léxicamente* 🤓📃 - Cada lenguaje de programación tiene su propio diccionario, es más simple que el diccionario de cualquier idioma natural.
#
# *Sintácticamente* 👾👈- Cada lenguaje tiene sus propias reglas. Es como la gramática en un idioma.
#
# *Semánticamente* 😉🤖 - Tu programa debe tener sentido y hacer lo que se supone que debe hacer.
#
# 7 **Compilación vs. Interpretación – Ventajas y Desventajas**
#
# Compilación 🧐
#
# Ventajas 😉
#
# 1.Ejecucion Rapida
#
# 2.Puede usar sin codigo
#
# 3.El codigo traducido es tu secreto.
#
# **Desventajas** ❌
#
# 1. la copilacion no puede ejecutar inmediatamente
#
# 2. Debes tener compiladores como plataformas de hardware, que se ejecute tu código.
#
# ### **¿Qué significa todo esto para ti? 🤔**
#
# - Python es un **lenguaje interpretado**. Esto significa que hereda todas las ventajas y desventajas descritas, agrega algunas de sus características.
# - **Python es gratuito**. Esta es una de sus ventajas más importantes.
#
#
# **NUMEROS NATURALES**
#
# N ⊆ Z ⊆  R ⊆ lR
#
#   X2-1= 0
#
#   X2+1=0 =  √-1=i =
#
#  c= a+bi=->(a,b)
#
#   c=a-bi
#
#   ejemplo
#
# Conjunto de omega
# ∩= {1, 2, 3}
#
#  P(∩)={{1},{2},{3},{1,2},{1,3},{2,3},∩}
#
#  {}=Conjunto vacio.
#
#  Cond(∩)=3
#
#  cond(P(∩))=2^3 -> cond(P(∩)=2^code(∩)
#
#  **Producto Cartesiano**
#
#  Sea A, B Conjunto
#
#  A X B ={(a,b): aEA, b E B}
#
#  A= {1,2,3}
#
#  B={0,1}
#
#  A X B ={(1,0),(1,1),(2,0),(2,1),(3,0), (3,1)
#
#  Cond(A X B)= Cod (A) x cond(B)
#
#  N X N= {(0,0),(0,1),(0,2).....
#
#           (1,0),(1,1),(1,2)
#
#           (2,0),(2,1),(2,2)
#
#           (3,0),(3,1),(3,2)
#
#   RXR= ´(X,Y): XE R, Y E R}
#   R^2
#   R^3=R X R X R
#
#   R^n={(x1,x2,xn):x1 E R, X2 E R, ......XN E R
#
#   R^n={(x1,x2,xn):∀;E {1, n}, x E R}
#
#   {(X1, X2,X3, ) : ∀; E N,X E R}
#
#
#   ={(Xi)^∞ i=1  ∀; E N,X E R}
